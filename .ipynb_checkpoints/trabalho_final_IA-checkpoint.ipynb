# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.models import Sequential, load_model
from keras.optimizers import SGD
from keras.utils import np_utils
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Image parameters
width = 100
height = 100

get_binarized_data = False

# Training parameters
epochs = 100
batch_size = 5
neurons = 250

# %%
dataset = {'data': [], 'labels': []}

if get_binarized_data:
    list_types = ['benigno', 'maligno']
else:
    list_types = ['original_data/benigno', 'original_data/maligno']
# Benigno will be 0, and Maligno will be 1
for num_tipo, nome_tipo in enumerate(list_types):
    for i,file_name in enumerate(os.listdir(nome_tipo)):
        if i == 99:
            break
        img = cv2.imread(nome_tipo + '/' + file_name, 0)
        # reshape the image
        resized_image = cv2.resize(img, (width, height)) 
        # flatten the image
        resized_image = resized_image.reshape(-1)
        # append each image to the dataset
        dataset['data'].append(resized_image)
        # with respective label
        dataset['labels'].append(num_tipo)

# %%
# Converte array para nparray
dataset['data'] = np.array(dataset['data'])
dataset['labels'] = np.array(dataset['labels'])

# %%
# Reshape the data to a (70000, 28, 28) tensor
data = dataset['data'].reshape((dataset['data'].shape[0], width, height))

# Reshape the data to a (70000, 28, 28, 1) tensord
data = data[:, :, :, np.newaxis]

# Scale values from range of [0-255] to [0-1]
scaled_data = data / 255.0

# %%
# Split the dataset into training and test sets
(train_data, test_data, train_labels, test_labels) = train_test_split(
        scaled_data,
        dataset['labels'].astype("int"), 
        test_size = 0.20)

# Tranform training labels to one-hot encoding
train_labels = np_utils.to_categorical(train_labels, 2)

# Tranform test labels to one-hot encoding
test_labels = np_utils.to_categorical(test_labels, 2)

# %%
# Create a sequential model
model = Sequential()

# Add the first convolution layer
model.add(Convolution2D(
    filters = 50,
    kernel_size = (5, 5),
    padding = "same",
    input_shape = (width, height, 1)))

# Add a ReLU activation function
model.add(Activation(
    activation = "relu"))

# Add a pooling layer
model.add(MaxPooling2D(
    pool_size = (2, 2),
    strides =  (2, 2)))

# Add the second convolution layer
model.add(Convolution2D(
    filters = 20,
    kernel_size = (5, 5),
    padding = "same"))

# Add a ReLU activation function
model.add(Activation(
    activation = "relu"))

# Add a second pooling layer
model.add(MaxPooling2D(
    pool_size = (2, 2),
    strides = (2, 2)))

# Flatten the network
model.add(Flatten())

# Add a fully-connected hidden layer
model.add(Dense(neurons))

# Add a ReLU activation function
model.add(Activation(
    activation = "relu"))

# Add a fully-connected output layer
model.add(Dense(2))

# Add a softmax activation function
model.add(Activation("softmax"))

# Compile the network
model.compile(
    loss = "categorical_crossentropy", 
    optimizer = SGD(lr = 0.01),
    metrics = ["accuracy"])

# Train the model 
history = model.fit(
    train_data, 
    train_labels, 
    batch_size = batch_size, 
    epochs = epochs,
    verbose = 1,
    validation_data=(test_data, test_labels))

# Evaluate the model
(loss, accuracy) = model.evaluate(
    test_data, 
    test_labels,
    batch_size = batch_size, 
    verbose = 1)
# Out:
# WARNING:tensorflow:From /home/cesar/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/cesar/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on
100
# 159/159 [==============================] - 2s 13ms/step - loss: 0.5016 - acc: 0.7484 - val_loss: 0.4058 - val_acc: 0.8500
# Epoch 89/100
# 159/159 [==============================] - 2s 14ms/step - loss: 0.4975 - acc: 0.7484 - val_loss: 0.6747 - val_acc: 0.5750
# Epoch 90/100
# 159/159 [==============================] - 2s 13ms/step - loss: 0.5186 - acc: 0.7547 - val_loss: 0.4481 - val_acc: 0.8500
# Epoch 91/100
# 159/159 [==============================] - 2s 10ms/step - loss: 0.5077 - acc: 0.7421 - val_loss: 0.4859 - val_acc: 0.7750
# Epoch 92/100
# 159/159 [==============================] - 2s 12ms/step - loss: 0.5042 - acc: 0.7987 - val_loss: 0.4958 - val_acc: 0.7750
# Epoch 93/100
# 159/159 [==============================] - 2s 13ms/step - loss: 0.5324 - acc: 0.7170 - val_loss: 0.5291 - val_acc: 0.7250
# Epoch 94/100
# 159/159 [==============================] - 2s 11ms/step - loss: 0.4781 - acc: 0.7736 - val_loss: 0.4428 - val_acc: 0.7750
# Epoch 95/100
# 159/159 [==============================] - 2s 11ms/step - loss: 0.4709 - acc: 0.7673 - val_loss: 0.4011 - val_acc: 0.7750
# Epoch 96/100
# 159/159 [==============================] - 2s 11ms/step - loss: 0.5266 - acc: 0.7484 - val_loss: 0.5382 - val_acc: 0.6750
# Epoch 97/100
# 159/159 [==============================] - 2s 12ms/step - loss: 0.5366 - acc: 0.7233 - val_loss: 0.4383 - val_acc: 0.8500
# Epoch 98/100
# 159/159 [==============================] - 2s 13ms/step - loss: 0.4730 - acc: 0.7610 - val_loss: 0.7039 - val_acc: 0.5500
# Epoch 99/100
# 159/159 [==============================] - 2s 13ms/step - loss: 0.4700 - acc: 0.7673 - val_loss: 0.4221 - val_acc: 0.8250
# Epoch 100/100
# 159/159 [==============================] - 2s 11ms/step - loss: 0.4457 - acc: 0.7736 - val_loss: 0.4277 - val_acc: 0.7750
# 40/40 [==============================] - 0s 4ms/step

# %%
print_test_results(history)

# %%
print_train_results(history)

# %%
print_test_results(history)

# %%
def print_test_results(history):
    plt.plot(history.history['val_acc'])
    plt.plot(history.history['val_loss'])
    plt.title('Resultados no teste')
    plt.ylabel('Taxa')
    plt.xlabel('Época')
    plt.legend(['Acurácia', 'Entropia cruzada'], loc='best')
    plt.grid()
    plt.show()


def print_train_results(history):
    plt.plot(history.history['acc'])
    plt.plot(history.history['loss'])
    plt.title('Resultados no treinamento')
    plt.ylabel('Taxa')
    plt.xlabel('Época')
    plt.legend(['Acurácia', 'Entropia cruzada'], loc='best')
    plt.grid()
    plt.show()

# %%
# Inicializar a rede com os pesos do MNIST

model = load_model('lenet_4_6_250neurons.h5')

model.pop()
model.pop()

# Add a fully-connected output layer
model.add(Dense(2))

# Add a softmax activation function
model.add(Activation("softmax"))

# Compile the network
model.compile(
    loss = "categorical_crossentropy", 
    optimizer = SGD(lr = 0.01),
    metrics = ["accuracy"])

# Train the model 
history = model.fit(
    train_data, 
    train_labels, 
    batch_size = 5, 
    epochs = 500,
    verbose = 1,
    validation_data=(test_data, test_labels))

# Evaluate the model
(loss, accuracy) = model.evaluate(
    test_data, 
    test_labels,
    batch_size = 5, 
    verbose = 1)
# Out:
# Train on 158 samples, validate on 40 samples
# Epoch 1/500
# 158/158 [==============================] - 1s 9ms/step - loss: 8.3829 - acc: 0.4684 - val_loss: 6.4472 - val_acc: 0.6000
# Epoch